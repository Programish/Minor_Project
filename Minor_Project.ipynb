# %%
import numpy as np
from numpy import asarray
from PIL import Image
from matplotlib import image
from matplotlib import pyplot

# %%
import os
path = os.listdir('dataset/')

# %%
for files in path:
    print(files)
# Out:
# w110.jpg
# w111.jpg
# w1110.jpg
# w11100.jpg
# w11101.jpg
# w11102.jpg
# w11103.jpg
# w11104.jpg
# w11105.jpg
# w11106.jpg
# w11107.jpg
# w11108.jpg
# w11109.jpg
# w1111.jpg
# w11110.jpg
# w11111.jpg
# w11112.jpg
# w11113.jpg
# w11114.jpg
# w11115.jpg
# w11116.jpg
# w11117.jpg
# w11118.jpg
# w11119.jpg
# w1112.jpg
# w11120.jpg
# w11121.jpg
# w11122.jpg
# w11123.jpg
# w11124.jpg
# w11125.jpg
# w11126.jpg
# w11127.jpg
# w11128.jpg
# w11129.jpg
# w1113.jpg
# w11130.jpg
# w11131.jpg
# w11132.jpg
# w11133.jpg
# w11134.jpg
# w11135.jpg
# w11136.jpg
# w11137.jpg
# w11138.jpg
# w11139.jpg
# w1114.jpg
# w11140.jpg
# w11141.jpg
# w11142.jpg
# w11143.jpg
# w11144.jpg
# w11145.jpg
# w11146.jpg
# w11147.jpg
# w11148.jpg
# w11149.jpg
# w1115.jpg
# w11150.jpg
# w11151.jpg
# w11152.jpg
# w11153.jpg
# w11154.jpg
# w11155.jpg
# w11156.jpg
# w11157.jpg
# w11158.jpg
# w11159.jpg
# w1116.jpg
# w11160.jpg
# w11161.jpg
# w11162.jpg
# w11163.jpg
# w11164.jpg
# w11165.jpg
# w11166.jpg
# w11167.jpg
# ...

# %%
for file in path:
    im = Image.open('dataset/'+file)
    data = asarray(im)
    print(type(data))
    print(data.shape)
# Out:
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# <class 'numpy.ndarray'>
# (512, 1024, 3)
# ...

# %%
im = asarray(Image.open('dataset/w111.jpg'))
print(im.shape)
# Out:
# (512, 1024, 3)

# %%
im = np.array(Image.open('dataset/w111.jpg'))
im_trim = im[0:513, 512:]
print(im_trim.shape)
# Out:
# (512, 512, 3)

# %%
gr_im= Image.fromarray(im_trim).save('w111_trim.png')

# %%
#output files
for file in path:
    im = np.array(Image.open('dataset/'+file))
    im_trim = im[0:513, 0:512]
    gr_im= Image.fromarray(im_trim).save('output/'+file)

# %%
#input files
for file in path:
    im = np.array(Image.open('dataset/'+file))
    im_trim = im[0:513, 512:]
    gr_im= Image.fromarray(im_trim).save('input/'+file)

# %%
#input array
X = []
input_path = os.listdir('input/')
for file in input_path:
    im = np.array(Image.open('input/'+file))
    im_reshape = im.reshape(-1)
    X.append(im_reshape)

# %%
#output array
y = []
output_path = os.listdir('output/')
for file in output_path:
    im = np.array(Image.open('output/'+file))
    im_reshape = im.reshape(-1)
    y.append(im_reshape)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-ad50428d3574> in <module>
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 print(confusion_matrix(y_test, y_pred))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     294
#     295     """
# --> 296     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     297     if y_type not in ("binary", "multiclass"):
#     298         raise ValueError("%s is not supported" % y_type)
#
# ...
